# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
import os


# Path to the ZIP file
zip_path = '/content/drive/MyDrive/CatVsDog/archive (6).zip'

# Extraction path
extract_path = '/content/catvsdog'

# Extract the ZIP file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# List extracted files
print("Extracted files:", os.listdir(extract_path))
# Out:
# Extracted files: ['train', 'dogs_vs_cats', 'test']

# %%
import os

# Check the structure of the 'train' folder
train_dir = '/content/catvsdog/train'
print("Train directory contents:", os.listdir(train_dir))

# Check the structure of the 'test' folder
test_dir = '/content/catvsdog/test'
print("Test directory contents:", os.listdir(test_dir))
# Out:
# Train directory contents: ['dogs', 'cats']
# Test directory contents: ['dogs', 'cats']

# %%
import os
from PIL import Image

def check_images(directory):
    for root, _, files in os.walk(directory):
        for file in files:
            file_path = os.path.join(root, file)
            try:
                with Image.open(file_path) as img:
                    img.verify()  # Verify the file integrity
            except (IOError, SyntaxError) as e:
                print(f"Corrupted image found: {file_path}")

# Check both train and test directories
check_images('/content/catvsdog/train')
check_images('/content/catvsdog/test')

# %%
import os

# Paths to train and test directories
train_dir = '/content/catvsdog/train'
test_dir = '/content/catvsdog/test'

def count_images_in_folder(folder_path):
    # Dictionary to store counts for each subfolder
    image_counts = {}
    for subfolder in os.listdir(folder_path):
        subfolder_path = os.path.join(folder_path, subfolder)
        if os.path.isdir(subfolder_path):
            # Count all files in the subfolder
            image_counts[subfolder] = len([
                f for f in os.listdir(subfolder_path)
                if os.path.isfile(os.path.join(subfolder_path, f))
            ])
    return image_counts

# Count images in train and test directories
train_image_counts = count_images_in_folder(train_dir)
test_image_counts = count_images_in_folder(test_dir)

print("Train Image Counts:", train_image_counts)
print("Test Image Counts:", test_image_counts)
# Out:
# Train Image Counts: {'dogs': 10000, 'cats': 10000}
# Test Image Counts: {'dogs': 2500, 'cats': 2500}

# %%
import sys
from matplotlib import pyplot as plt
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Define the CNN model
def define_model():
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform',
                     padding='same', input_shape=(200, 200, 3)))
    model.add(MaxPooling2D((2, 2)))
    model.add(Flatten())
    model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
    model.add(Dense(1, activation='sigmoid'))
    opt = Adam(learning_rate=0.0001)
    model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
import numpy as np
import pandas as pd

# Run the test harness for evaluating a model
def run_test_harness():
    model = define_model()
    datagen = ImageDataGenerator(rescale=1.0/255.0)

    # Prepare iterators for training and testing datasets
    train_it = datagen.flow_from_directory(
        '/content/catvsdog/train/',
        batch_size=32,
        target_size=(200, 200),
        class_mode='binary'
    )

    test_it = datagen.flow_from_directory(
        '/content/catvsdog/test/',
        batch_size=32,
        target_size=(200, 200),
        class_mode='binary'
    )

    # Store accuracy and loss values
    train_acc = []
    val_acc = []
    train_loss = []
    val_loss = []

    # Fit the model with correct steps_per_epoch and validation_steps
    history = model.fit(
        train_it,
        validation_data=test_it,
        epochs=40,
    )

    # Extract accuracy and loss values for each epoch
    for epoch in range(40):  # assuming 40 epochs
        train_acc.append(history.history['accuracy'][epoch])
        val_acc.append(history.history['val_accuracy'][epoch])
        train_loss.append(history.history['loss'][epoch])
        val_loss.append(history.history['val_loss'][epoch])

    # Save the values in a DataFrame or CSV
    data = {
        'Epoch': np.arange(1, 41),
        'Train Accuracy': train_acc,
        'Val Accuracy': val_acc,
        'Train Loss': train_loss,
        'Val Loss': val_loss
    }

    df = pd.DataFrame(data)
    df.to_csv('/content/training_history.csv', index=False)  # Save to CSV in the Colab directory

    print(df)

# Call the function to run the test harness

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_from_csv(file_path):
    # Read the CSV file
    data = pd.read_csv(file_path)

    # Check if required columns exist
    required_columns = {"Epoch", "Train Accuracy", "Val Accuracy", "Train Loss", "Val Loss"}
    if not required_columns.issubset(data.columns):
        print(f"CSV file must contain the columns: {required_columns}")
        return

    # Plot accuracy
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(data['Epoch'], data['Train Accuracy'], label='Train Accuracy', marker='o')
    plt.plot(data['Epoch'], data['Val Accuracy'], label='Validation Accuracy', marker='o')
    plt.title('Accuracy over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)

    # Plot loss
    plt.subplot(1, 2, 2)
    plt.plot(data['Epoch'], data['Train Loss'], label='Train Loss', marker='o')
    plt.plot(data['Epoch'], data['Val Loss'], label='Validation Loss', marker='o')
    plt.title('Loss over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    # Show plots
    plt.tight_layout()
    plt.show()

# %%
plot_from_csv('/content/training_history01.csv')

# %%
def define_model():
    # Initialize the model
    model = Sequential()

    # Add layers
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform',
                     padding='same', input_shape=(200, 200, 3)))
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform',
                     padding='same'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Flatten())
    model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
    model.add(Dense(1, activation='sigmoid'))  # Sigmoid for binary classification

    # Compile the model
    opt = Adam(learning_rate=0.0001)
    model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])

    return model

# %%
run_test_harness()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Found 20000 images belonging to 2 classes.
# Found 5000 images belonging to 2 classes.
# Epoch 1/40
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 56s 81ms/step - accuracy: 0.6057 - loss: 0.8074 - val_accuracy: 0.7370 - val_loss: 0.5326
# Epoch 2/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 78s 81ms/step - accuracy: 0.7582 - loss: 0.4995 - val_accuracy: 0.7778 - val_loss: 0.4824
# Epoch 3/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 51s 81ms/step - accuracy: 0.8009 - loss: 0.4334 - val_accuracy: 0.7756 - val_loss: 0.4728
# Epoch 4/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 83s 82ms/step - accuracy: 0.8410 - loss: 0.3719 - val_accuracy: 0.7416 - val_loss: 0.5328
# Epoch 5/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 80s 80ms/step - accuracy: 0.8661 - loss: 0.3246 - val_accuracy: 0.7844 - val_loss: 0.4669
# Epoch 6/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 83s 81ms/step - accuracy: 0.8908 - loss: 0.2740 - val_accuracy: 0.7942 - val_loss: 0.4673
# Epoch 7/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 51s 81ms/step - accuracy: 0.9220 - loss: 0.2223 - val_accuracy: 0.7954 - val_loss: 0.4845
# Epoch 8/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━
# 28     29         1.00000        0.7886    0.000359  1.279400
# 29     30         1.00000        0.7854    0.000286  1.310359
# 30     31         1.00000        0.7874    0.000211  1.347755
# 31     32         1.00000        0.7844    0.000181  1.375430
# 32     33         1.00000        0.7860    0.000127  1.422023
# 33     34         1.00000        0.7844    0.000089  1.474288
# 34     35         1.00000        0.7864    0.000063  1.504008
# 35     36         1.00000        0.7842    0.000049  1.537282
# 36     37         0.98720        0.7842    0.045219  1.235386
# 37     38         0.99965        0.7848    0.002158  1.309468
# 38     39         0.99885        0.7586    0.004108  1.559974
# 39     40         0.99690        0.7798    0.010672  1.411273
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-c1b3612b5def> in <cell line: 1>()
# ----> 1 run_test_harness()
#
# <ipython-input-13-c3cf5b8988e1> in run_test_harness()
#      57
#      58     # Evaluate the model
# ---> 59     _, acc = model.evaluate(test_it, steps=val_steps, verbose=0)
#      60     print('> Accuracy: %.3f' % (acc * 100.0))
#      61
#
# NameError: name 'val_steps' is not defined

# %%
plot_from_csv('/content/training_history02.csv')

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.optimizers import SGD

def define_model():
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform',
                     padding='same', input_shape=(200, 200, 3)))
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform',
                     padding='same'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform',
                     padding='same'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Flatten())
    model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
    model.add(Dense(1, activation='sigmoid'))

    # Compile the model
    opt = Adam(learning_rate=0.0001)
    model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])

    return model

# %%
run_test_harness()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Found 20000 images belonging to 2 classes.
# Found 5000 images belonging to 2 classes.
# Epoch 1/40
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 57s 84ms/step - accuracy: 0.6185 - loss: 0.7747 - val_accuracy: 0.7570 - val_loss: 0.5025
# Epoch 2/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 51s 81ms/step - accuracy: 0.7785 - loss: 0.4689 - val_accuracy: 0.7886 - val_loss: 0.4623
# Epoch 3/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 52s 83ms/step - accuracy: 0.8265 - loss: 0.3941 - val_accuracy: 0.8068 - val_loss: 0.4312
# Epoch 4/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 83ms/step - accuracy: 0.8603 - loss: 0.3266 - val_accuracy: 0.8164 - val_loss: 0.4187
# Epoch 5/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 53s 84ms/step - accuracy: 0.8958 - loss: 0.2607 - val_accuracy: 0.8170 - val_loss: 0.4219
# Epoch 6/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 53s 84ms/step - accuracy: 0.9167 - loss: 0.2166 - val_accuracy: 0.8156 - val_loss: 0.4343
# Epoch 7/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 51s 81ms/step - accuracy: 0.9404 - loss: 0.1638 - val_accuracy: 0.8202 - val_loss: 0.4424
# Epoch 8/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 81s 80ms/step - accuracy: 0.9584 - loss: 0.1235 - val_accuracy: 0.8194 - val_loss: 0.4806
# Epoch 9/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 80ms/step - accuracy: 0.9790 - loss: 0.0778 - val_accuracy: 0.8100 - val_loss: 0.5534
# Epoch 10/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 85s 84ms/step - accuracy: 0.9823 - loss: 0.0638 - val_accuracy: 0.8156 - val_loss: 0.5582
# Epoch 11/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━
40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 50s 80ms/step - accuracy: 1.0000 - loss: 3.0322e-05 - val_accuracy: 0.8248 - val_loss: 1.2901
# Epoch 35/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 84s 83ms/step - accuracy: 1.0000 - loss: 2.3698e-05 - val_accuracy: 0.8236 - val_loss: 1.3175
# Epoch 36/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 84ms/step - accuracy: 1.0000 - loss: 1.7167e-05 - val_accuracy: 0.8234 - val_loss: 1.3559
# Epoch 37/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 84ms/step - accuracy: 1.0000 - loss: 1.1572e-05 - val_accuracy: 0.8246 - val_loss: 1.3829
# Epoch 38/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 53s 84ms/step - accuracy: 1.0000 - loss: 8.5277e-06 - val_accuracy: 0.8242 - val_loss: 1.4144
# Epoch 39/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 81s 82ms/step - accuracy: 1.0000 - loss: 5.9163e-06 - val_accuracy: 0.8252 - val_loss: 1.4459
# Epoch 40/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 52s 83ms/step - accuracy: 1.0000 - loss: 4.2014e-06 - val_accuracy: 0.8240 - val_loss: 1.4848
#     Epoch  Train Accuracy  Val Accuracy  Train Loss  Val Loss
# 0       1         0.67965        0.7570    0.614437  0.502533
# 1       2         0.77935        0.7886    0.467714  0.462307
# 2       3         0.82815        0.8068    0.388151  0.431201
# 3       4         0.85725        0.8164    0.334059  0.418738
# 4       5         0.88970        0.8170    0.270292  0.421917
# 5       6         0.91355        0.8156    0.218177  0.434282
# 6       7         0.93500        0.8202    0.170120  0.442399
# 7       8         0.95660        0.8194    0.125488  0.480551
# 8       9         0.97430        0.8100    0.085535  0.553391
# 9      10         0.98205        0.8156    0.064826  0.558240
# 10     11         0.98910        0.8134    0.045992  0.616202
# 11     12         0.98995        0.8142    0.039580  0.653625
# 12     13         0.99315        0.8040    0.029389  0.752270
# 13     14         0.99690        0.8192    0.019201  0.703965
# 14     15         0.99535        0.8104    0.020572  0.748526
# 15     16         0.99400        0.8138    0.022677  0.732956
# 16     17         0.99750        0.8156    0.012364  0.816902
# 17     18         0.99955        0.8216    0.006367  0.847681
# 18     19         0.99985        0.8102    0.002231  0.940205
# 19     20         0.98905        0.8158    0.034509  0.813485
# 20     21         0.99870        0.8162    0.007567  0.853403
# 21     22         0.99700        0.8134    0.012639  0.935492
# 22     23         0.99610        0.8178    0.014139  0.924692
# 23     24         0.99960        0.8174    0.002903  0.944565
# 24     25         1.00000        0.8238    0.000831  0.990674
# 25     26         1.00000        0.8250    0.000358  1.036325
# 26     27         1.00000        0.8220    0.000244  1.069896
# 27     28         1.00000        0.8250    0.000181  1.100624
# 28     29         1.00000        0.8220    0.000133  1.132441
# 29     30         1.00000        0.8238    0.000102  1.159918
# 30     31         1.00000        0.8232    0.000078  1.182098
# 31     32         1.00000        0.8232    0.000057  1.218767
# 32     33         1.00000        0.8222    0.000042  1.253390
# 33     34         1.00000        0.8248    0.000030  1.290130
# 34     35         1.00000        0.8236    0.000023  1.317538
# 35     36         1.00000        0.8234    0.000016  1.355927
# 36     37         1.00000        0.8246    0.000012  1.382858
# 37     38         1.00000        0.8242    0.000008  1.414429
# 38     39         1.00000        0.8252    0.000006  1.445929
# 39     40         1.00000        0.8240    0.000004  1.484838

# %%
plot_from_csv('/content/training_history03.csv')

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

def define_model():
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform',
                     padding='same', input_shape=(200, 200, 3)))
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.2))

    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform',
                     padding='same'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.2))

    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform',
                     padding='same'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.2))

    model.add(Flatten())
    model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
    model.add(Dropout(0.5))

    model.add(Dense(1, activation='sigmoid'))

    # Compile the model
    opt = Adam(learning_rate=0.0001)
    model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])

    return model

# %%
run_test_harness()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Found 20000 images belonging to 2 classes.
# Found 5000 images belonging to 2 classes.
# Epoch 1/40
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 58s 83ms/step - accuracy: 0.5015 - loss: 0.8647 - val_accuracy: 0.5002 - val_loss: 0.6931
# Epoch 2/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 81s 88ms/step - accuracy: 0.5018 - loss: 0.6934 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 3/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 54s 85ms/step - accuracy: 0.5037 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 4/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 53s 84ms/step - accuracy: 0.4962 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 5/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 54s 85ms/step - accuracy: 0.4937 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 6/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 81s 83ms/step - accuracy: 0.4934 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 7/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 83s 86ms/step - accuracy: 0.5013 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 8/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 86ms/step - accuracy: 0.4980 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 9/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 52s 83ms/step - accuracy: 0.4985 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 10/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 84s 86ms/step - accuracy: 0.4961 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 11/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 53s 83ms/step - accuracy: 0.5107 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 12/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 55s 86ms/step - accuracy: 0.4996 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 13/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 54s 86ms/step - accuracy: 0.4918 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 14/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 83s 87ms/step - accuracy: 0.5008 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 15/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 80s 85ms/step - accuracy: 0.4921 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 16/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 84s 89ms/step - accuracy: 0.4959 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 17/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 89ms/step - accuracy: 0.4978 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 18/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 56s 88ms/step - accuracy: 0.5015 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 19/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 81s 86ms/step - accuracy: 0.4971 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 20/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 81s 85ms/step - accuracy: 0.4990 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 21/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 55s 87ms/step - accuracy: 0.5039 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 22/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 87ms/step - accuracy: 0.5015 - loss: 0.6932 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 23/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 81s 86ms/step - accuracy: 0.5018 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 24/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 86ms/step - accuracy: 0.4999 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 25/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 85ms/step - accuracy: 0.5000 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 26/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 55s 87ms/step - accuracy: 0.4985 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 27/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 55s 88ms/step - accuracy: 0.5059 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 28/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 55s 88ms/step - accuracy: 0.5005 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch 29/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 88ms/step - accuracy: 0.5035 - loss: 0.6931 - val_accuracy: 0.5000 - val_loss: 0.6931
# Epoch
# %% [markdown]
# <a href="https://colab.research.google.com/github/Riyaz402p/Classifcation_Infosys_Internship_Oct2024/blob/main/CD01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !kaggle datasets download -d dinesh873/dog-vs-cat-data
# Out:
# Dataset URL: https://www.kaggle.com/datasets/dinesh873/dog-vs-cat-data
# License(s): MIT
# Downloading dog-vs-cat-data.zip to /content
#  99% 1.06G/1.06G [00:16<00:00, 86.7MB/s]
# 100% 1.06G/1.06G [00:16<00:00, 71.0MB/s]

# %%
import zipfile
import os


# Path to the ZIP file
zip_path = '/content/dog-vs-cat-data.zip'

# Extraction path
extract_path = '/content/catvsdog'

# Extract the ZIP file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# List extracted files
print("Extracted files:", os.listdir(extract_path))
# Out:
# Extracted files: ['train', 'dogs_vs_cats', 'test']

# %%
import os

# Check the structure of the 'train' folder
train_dir = '/content/catvsdog/train'
print("Train directory contents:", os.listdir(train_dir))

# Check the structure of the 'test' folder
test_dir = '/content/catvsdog/test'
print("Test directory contents:", os.listdir(test_dir))
# Out:
# Train directory contents: ['dogs', 'cats']
# Test directory contents: ['dogs', 'cats']

# %%
import os
from PIL import Image

def check_images(directory):
    for root, _, files in os.walk(directory):
        for file in files:
            file_path = os.path.join(root, file)
            try:
                with Image.open(file_path) as img:
                    img.verify()  # Verify the file integrity
            except (IOError, SyntaxError) as e:
                print(f"Corrupted image found: {file_path}")

# Check both train and test directories
check_images('/content/catvsdog/train')
check_images('/content/catvsdog/test')

# %%
import os

# Paths to train and test directories
train_dir = '/content/catvsdog/train'
test_dir = '/content/catvsdog/test'

def count_images_in_folder(folder_path):
    # Dictionary to store counts for each subfolder
    image_counts = {}
    for subfolder in os.listdir(folder_path):
        subfolder_path = os.path.join(folder_path, subfolder)
        if os.path.isdir(subfolder_path):
            # Count all files in the subfolder
            image_counts[subfolder] = len([
                f for f in os.listdir(subfolder_path)
                if os.path.isfile(os.path.join(subfolder_path, f))
            ])
    return image_counts

# Count images in train and test directories
train_image_counts = count_images_in_folder(train_dir)
test_image_counts = count_images_in_folder(test_dir)

print("Train Image Counts:", train_image_counts)
print("Test Image Counts:", test_image_counts)
# Out:
# Train Image Counts: {'dogs': 10000, 'cats': 10000}
# Test Image Counts: {'dogs': 2500, 'cats': 2500}

# %%
import sys
from matplotlib import pyplot as plt
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Define the CNN model
def define_model():
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform',
                     padding='same', input_shape=(200, 200, 3)))
    model.add(MaxPooling2D((2, 2)))
    model.add(Flatten())
    model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
    model.add(Dense(1, activation='sigmoid'))
    opt = Adam(learning_rate=0.0001)
    model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
import numpy as np
import pandas as pd

# Run the test harness for evaluating a model
def run_test_harness():
    model = define_model()
    datagen = ImageDataGenerator(rescale=1.0/255.0)

    # Prepare iterators for training and testing datasets
    train_it = datagen.flow_from_directory(
        '/content/catvsdog/train/',
        batch_size=32,
        target_size=(200, 200),
        class_mode='binary'
    )

    test_it = datagen.flow_from_directory(
        '/content/catvsdog/test/',
        batch_size=32,
        target_size=(200, 200),
        class_mode='binary'
    )

    # Store accuracy and loss values
    train_acc = []
    val_acc = []
    train_loss = []
    val_loss = []

    # Fit the model with correct steps_per_epoch and validation_steps
    history = model.fit(
        train_it,
        validation_data=test_it,
        epochs=40,
    )

    # Extract accuracy and loss values for each epoch
    for epoch in range(40):  # assuming 40 epochs
        train_acc.append(history.history['accuracy'][epoch])
        val_acc.append(history.history['val_accuracy'][epoch])
        train_loss.append(history.history['loss'][epoch])
        val_loss.append(history.history['val_loss'][epoch])

    # Save the values in a DataFrame or CSV
    data = {
        'Epoch': np.arange(1, 41),
        'Train Accuracy': train_acc,
        'Val Accuracy': val_acc,
        'Train Loss': train_loss,
        'Val Loss': val_loss
    }

    df = pd.DataFrame(data)
    df.to_csv('/content/training_history.csv', index=False)  # Save to CSV in the Colab directory

    print(df)

# Call the function to run the test harness

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_from_csv(file_path):
    # Read the CSV file
    data = pd.read_csv(file_path)

    # Check if required columns exist
    required_columns = {"Epoch", "Train Accuracy", "Val Accuracy", "Train Loss", "Val Loss"}
    if not required_columns.issubset(data.columns):
        print(f"CSV file must contain the columns: {required_columns}")
        return

    # Plot accuracy
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(data['Epoch'], data['Train Accuracy'], label='Train Accuracy', marker='o')
    plt.plot(data['Epoch'], data['Val Accuracy'], label='Validation Accuracy', marker='o')
    plt.title('Accuracy over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)

    # Plot loss
    plt.subplot(1, 2, 2)
    plt.plot(data['Epoch'], data['Train Loss'], label='Train Loss', marker='o')
    plt.plot(data['Epoch'], data['Val Loss'], label='Validation Loss', marker='o')
    plt.title('Loss over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    # Show plots
    plt.tight_layout()
    plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_from_csv(file_path):
    # Read the CSV file
    try:  # Add a try-except block to handle the FileNotFoundError
        data = pd.read_csv(file_path)
    except FileNotFoundError:
        print(f"File not found: {file_path}")
        print("Make sure 'run_test_harness()' has been executed and the file exists.")
        return

    # Check if required columns exist
    required_columns = {"Epoch", "Train Accuracy", "Val Accuracy", "Train Loss", "Val Loss"}
    if not required_columns.issubset(data.columns):
        print(f"CSV file must contain the columns: {required_columns}")
        return

    # Plot accuracy
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(data['Epoch'], data['Train Accuracy'], label='Train Accuracy', marker='o')
    plt.plot(data['Epoch'], data['Val Accuracy'], label='Validation Accuracy', marker='o')
    plt.title('Accuracy over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)

    # Plot loss
    plt.subplot(1, 2, 2)
    plt.plot(data['Epoch'], data['Train Loss'], label='Train Loss', marker='o')
    plt.plot(data['Epoch'], data['Val Loss'], label='Validation Loss', marker='o')
    plt.title('Loss over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    # Show plots
    plt.tight_layout()
    plt.show()

# %%
run_test_harness()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Found 20000 images belonging to 2 classes.
# Found 5000 images belonging to 2 classes.
# Epoch 1/40
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 53s 83ms/step - accuracy: 0.5684 - loss: 1.3247 - val_accuracy: 0.5284 - val_loss: 0.9749
# Epoch 2/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 77s 76ms/step - accuracy: 0.6604 - loss: 0.6490 - val_accuracy: 0.6526 - val_loss: 0.6352
# Epoch 3/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 84s 79ms/step - accuracy: 0.7436 - loss: 0.5165 - val_accuracy: 0.6632 - val_loss: 0.6662
# Epoch 4/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 53s 85ms/step - accuracy: 0.7852 - loss: 0.4594 - val_accuracy: 0.6554 - val_loss: 0.6561
# Epoch 5/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 81s 84ms/step - accuracy: 0.8259 - loss: 0.3991 - val_accuracy: 0.7054 - val_loss: 0.5783
# Epoch 6/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 52s 82ms/step - accuracy: 0.8570 - loss: 0.3462 - val_accuracy: 0.7336 - val_loss: 0.5561
# Epoch 7/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 82ms/step - accuracy: 0.8809 - loss: 0.3042 - val_accuracy: 0.7162 - val_loss: 0.5908
# Epoch 8/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 83ms/step - accuracy: 0.9045 - loss: 0.2614 - val_accuracy: 0.7362 - val_loss: 0.5679
# Epoch 9/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 80s 80ms/step - accuracy: 0.9350 - loss: 0.2079 - val_accuracy: 0.7360 - val_loss: 0.5862
# Epoch 10/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 51s 81ms/step - accuracy: 0.9458 - loss: 0.1823 - val_accuracy: 0.7284 - val_loss: 0.6435
# Epoch 11/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 81s 79ms/step - accuracy: 0.9647 - loss: 0.1430 - val_accuracy: 0.7308 - val_loss: 0.6496
# Epoch 12/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 84s 82ms/step - accuracy: 0.9720 - loss: 0.1237 - val_accuracy: 0.7260 - val_loss: 0.7097
# Epoch 13/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 83s 84ms/step - accuracy: 0.9824 - loss: 0.0938 - val_accuracy: 0.7258 - val_loss: 0.7408
# Epoch 14/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 79s
# 14     15         0.99085        0.7276    0.062023  0.823858
# 15     16         0.99205        0.7262    0.051234  0.856752
# 16     17         0.99390        0.7276    0.043973  0.893970
# 17     18         0.99745        0.7248    0.030376  0.963057
# 18     19         0.99360        0.7310    0.036703  0.984093
# 19     20         0.99525        0.7206    0.028930  1.047452
# 20     21         0.99960        0.7112    0.015137  1.216685
# 21     22         0.99940        0.7288    0.012653  1.092741
# 22     23         1.00000        0.7298    0.007910  1.147295
# 23     24         0.99475        0.7220    0.020892  1.155161
# 24     25         0.99450        0.7240    0.026426  1.232211
# 25     26         0.99485        0.7148    0.022314  1.270526
# 26     27         0.99890        0.7234    0.010833  1.266637
# 27     28         1.00000        0.7252    0.004323  1.289117
# 28     29         1.00000        0.7268    0.003261  1.341084
# 29     30         1.00000        0.7280    0.002641  1.349496
# 30     31         1.00000        0.7280    0.002178  1.376990
# 31     32         1.00000        0.7288    0.001762  1.429125
# 32     33         1.00000        0.7272    0.001421  1.445044
# 33     34         0.99265        0.7206    0.033141  1.361104
# 34     35         0.99685        0.7172    0.014067  1.453599
# 35     36         0.99730        0.7224    0.013877  1.449393
# 36     37         0.99880        0.7224    0.008069  1.487788
# 37     38         1.00000        0.7252    0.001629  1.510655
# 38     39         1.00000        0.7244    0.001218  1.532590
# 39     40         1.00000        0.7250    0.000989  1.556651

# %%
plot_from_csv('/content/training_history.csv')

# %%
def define_model():
    # Initialize the model
    model = Sequential()

    # Add layers
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform',
                     padding='same', input_shape=(200, 200, 3)))
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform',
                     padding='same'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Flatten())
    model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
    model.add(Dense(1, activation='sigmoid'))  # Sigmoid for binary classification

    # Compile the model
    opt = Adam(learning_rate=0.0001)
    model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])

    return model

# %%
plot_from_csv('/content/training_history02.csv')
# Out:
# File not found: /content/training_history02.csv
# Make sure 'run_test_harness()' has been executed and the file exists.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.optimizers import SGD

def define_model():
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform',
                     padding='same', input_shape=(200, 200, 3)))
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform',
                     padding='same'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform',
                     padding='same'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Flatten())
    model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
    model.add(Dense(1, activation='sigmoid'))

    # Compile the model
    opt = Adam(learning_rate=0.0001)
    model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])

    return model

# %%
run_test_harness()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Found 20000 images belonging to 2 classes.
# Found 5000 images belonging to 2 classes.
# Epoch 1/40
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 57s 84ms/step - accuracy: 0.6185 - loss: 0.7747 - val_accuracy: 0.7570 - val_loss: 0.5025
# Epoch 2/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 51s 81ms/step - accuracy: 0.7785 - loss: 0.4689 - val_accuracy: 0.7886 - val_loss: 0.4623
# Epoch 3/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 52s 83ms/step - accuracy: 0.8265 - loss: 0.3941 - val_accuracy: 0.8068 - val_loss: 0.4312
# Epoch 4/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 83ms/step - accuracy: 0.8603 - loss: 0.3266 - val_accuracy: 0.8164 - val_loss: 0.4187
# Epoch 5/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 53s 84ms/step - accuracy: 0.8958 - loss: 0.2607 - val_accuracy: 0.8170 - val_loss: 0.4219
# Epoch 6/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 53s 84ms/step - accuracy: 0.9167 - loss: 0.2166 - val_accuracy: 0.8156 - val_loss: 0.4343
# Epoch 7/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 51s 81ms/step - accuracy: 0.9404 - loss: 0.1638 - val_accuracy: 0.8202 - val_loss: 0.4424
# Epoch 8/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 81s 80ms/step - accuracy: 0.9584 - loss: 0.1235 - val_accuracy: 0.8194 - val_loss: 0.4806
# Epoch 9/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 80ms/step - accuracy: 0.9790 - loss: 0.0778 - val_accuracy: 0.8100 - val_loss: 0.5534
# Epoch 10/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 85s 84ms/step - accuracy: 0.9823 - loss: 0.0638 - val_accuracy: 0.8156 - val_loss: 0.5582
# Epoch 11/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 80s 82ms/step - accuracy: 0.9899 - loss: 0.0437 - val_accuracy: 0.8134 - val_loss: 0.6162
# Epoch 12/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 50s 80ms/step - accuracy: 0.9931 - loss: 0.0319 - val_accuracy: 0.8142 - val_loss: 0.6536
# Epoch 13/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 51s 81ms/step - accuracy: 0.9964 - loss: 0.0225 - val_accuracy: 0.8040 - val_loss: 0.7523
# Epoch 14/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 50s 79ms/step - accuracy: 0.9968 - loss: 0.0201 - val_accuracy: 0.8192 - val_loss: 0.7040
# Epoch 15/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 53s 84ms/step - accuracy: 0.9981 - loss: 0.0132 - val_accuracy: 0.8104 - val_loss: 0.7485
# Epoch 16/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 52s 83ms/step - accuracy: 0.9955 - loss: 0.0185 - val_accuracy: 0.8138 - val_loss: 0.7330
# Epoch 17/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 51s 81ms/step - accuracy: 0.9978 - loss: 0.0118 - val_accuracy: 0.8156 - val_loss: 0.8169
# Epoch 18/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 52s 83ms/step - accuracy: 0.9994 - loss: 0.0067 - val_accuracy: 0.8216 - val_loss: 0.8477
# Epoch 19/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 81s 82ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.8102 - val_loss: 0.9402
# Epoch 20/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 82ms/step - accuracy: 0.9865 - loss: 0.0407 - val_accuracy: 0.8158 - val_loss: 0.8135
# Epoch 21/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 52s 82ms/step - accuracy: 0.9984 - loss: 0.0087 - val_accuracy: 0.8162 - val_loss: 0.8534
# Epoch 22/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 83s 85ms/step - accuracy: 0.9977 - loss: 0.0102 - val_accuracy: 0.8134 - val_loss: 0.9355
# Epoch 23/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - accuracy: 0.9929 - loss: 0.0227 - val_accuracy: 0.8178 - val_loss: 0.9247
# Epoch 24/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 52s 83ms/step - accuracy: 0.9996 - loss: 0.0026 - val_accuracy: 0.8174 - val_loss: 0.9446
# Epoch 25/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 83ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.8238 - val_loss: 0.9907
# Epoch 26/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 51s 80ms/step - accuracy: 1.0000 - loss: 3.7905e-04 - val_accuracy: 0.8250 - val_loss: 1.0363
# Epoch 27/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 85s 85ms/step - accuracy: 1.0000 - loss: 2.4538e-04 - val_accuracy: 0.8220 - val_loss: 1.0699
# Epoch 28/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 80s 81ms/step - accuracy: 1.0000 - loss: 1.7875e-04 - val_accuracy: 0.8250 - val_loss: 1.1006
# Epoch 29/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 52s 83ms/step - accuracy: 1.0000 - loss: 1.3289e-04 - val_accuracy: 0.8220 - val_loss: 1.1324
# Epoch 30/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 52s 82ms/step - accuracy: 1.0000 - loss: 1.0265e-04 - val_accuracy: 0.8238 - val_loss: 1.1599
# Epoch 31/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 82ms/step - accuracy: 1.0000 - loss: 7.8421e-05 - val_accuracy: 0.8232 - val_loss: 1.1821
# Epoch 32/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 83ms/step - accuracy: 1.0000 - loss: 5.7105e-05 - val_accuracy: 0.8232 - val_loss: 1.2188
# Epoch 33/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 53s 84ms/step - accuracy: 1.0000 - loss: 4.2477e-05 - val_accuracy: 0.8222 - val_loss: 1.2534
# Epoch 34/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 50s 80ms/step - accuracy: 1.0000 - loss: 3.0322e-05 - val_accuracy: 0.8248 - val_loss: 1.2901
# Epoch 35/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 84s 83ms/step - accuracy: 1.0000 - loss: 2.3698e-05 - val_accuracy: 0.8236 - val_loss: 1.3175
# Epoch 36/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 84ms/step - accuracy: 1.0000 - loss: 1.7167e-05 - val_accuracy: 0.8234 - val_loss: 1.3559
# Epoch 37/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 82s 84ms/step - accuracy: 1.0000 - loss: 1.1572e-05 - val_accuracy: 0.8246 - val_loss: 1.3829
# Epoch 38/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 53s 84ms/step - accuracy: 1.0000 - loss: 8.5277e-06 - val_accuracy: 0.8242 - val_loss: 1.4144
# Epoch 39/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 81s 82ms/step - accuracy: 1.0000 - loss: 5.9163e-06 - val_accuracy: 0.8252 - val_loss: 1.4459
# Epoch 40/40
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 52s 83ms/step - accuracy: 1.0000 - loss: 4.2014e-06 - val_accuracy: 0.8240 - val_loss: 1.4848
#     Epoch  Train Accuracy  Val Accuracy  Train Loss  Val Loss
# 0       1         0.67965        0.7570    0.614437  0.502533
# 1       2         0.77935        0.7886    0.467714  0.462307
# 2       3         0.82815        0.8068    0.388151  0.431201
# 3       4         0.85725        0.8164    0.334059  0.418738
# 4       5         0.88970        0.8170    0.270292  0.421917
# 5       6         0.91355        0.8156    0.218177  0.434282
# 6       7         0.93500        0.8202    0.170120  0.442399

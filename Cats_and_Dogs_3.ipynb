# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import os

# Check the structure of the 'train' folder
train_dir = '/kaggle/input/catvsdog/test'
print("Train directory contents:", os.listdir(train_dir))

# Check the structure of the 'test' folder
test_dir = '/kaggle/input/catvsdog/train'
print("Test directory contents:", os.listdir(test_dir))
# Out:
# Train directory contents: ['dogs', 'cats']
# Test directory contents: ['dogs', 'cats']

# %%
import os

# Paths to train and test directories
train_dir = '/kaggle/input/catvsdog/train'
test_dir = '/kaggle/input/catvsdog/test'

def count_images_in_folder(folder_path):
    # Dictionary to store counts for each subfolder
    image_counts = {}
    for subfolder in os.listdir(folder_path):
        subfolder_path = os.path.join(folder_path, subfolder)
        if os.path.isdir(subfolder_path):
            # Count all files in the subfolder
            image_counts[subfolder] = len([
                f for f in os.listdir(subfolder_path)
                if os.path.isfile(os.path.join(subfolder_path, f))
            ])
    return image_counts

# Count images in train and test directories
train_image_counts = count_images_in_folder(train_dir)
test_image_counts = count_images_in_folder(test_dir)

print("Train Image Counts:", train_image_counts)
print("Test Image Counts:", test_image_counts)
# Out:
# Train Image Counts: {'dogs': 10000, 'cats': 10000}
# Test Image Counts: {'dogs': 2500, 'cats': 2500}

# %%
import sys
from matplotlib import pyplot as plt
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
def define_model():
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform',
                     padding='same', input_shape=(200, 200, 3)))
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.1))

    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform',
                     padding='same'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.1))

    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform',
                     padding='same'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.1))

    model.add(Flatten())
    model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
    model.add(Dropout(0.3))

    model.add(Dense(1, activation='sigmoid'))

    # Compile the model
    opt = Adam(learning_rate=0.0001)
    model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])

    return model

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_from_csv(file_path):
    # Read the CSV file
    data = pd.read_csv(file_path)

    # Check if required columns exist
    required_columns = {"Epoch", "Train Accuracy", "Val Accuracy", "Train Loss", "Val Loss"}
    if not required_columns.issubset(data.columns):
        print(f"CSV file must contain the columns: {required_columns}")
        return

    # Plot accuracy
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(data['Epoch'], data['Train Accuracy'], label='Train Accuracy', marker='o')
    plt.plot(data['Epoch'], data['Val Accuracy'], label='Validation Accuracy', marker='o')
    plt.title('Accuracy over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)

    # Plot loss
    plt.subplot(1, 2, 2)
    plt.plot(data['Epoch'], data['Train Loss'], label='Train Loss', marker='o')
    plt.plot(data['Epoch'], data['Val Loss'], label='Validation Loss', marker='o')
    plt.title('Loss over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    # Show plots
    plt.tight_layout()
    plt.show()

# %%
import numpy as np
import pandas as pd


# Define the test harness
def run_test_harness():
    model = define_model()

    # Data augmentation configuration
    datagen = ImageDataGenerator(
        rescale=1.0 / 255.0,
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip=True
    )

    # Prepare iterators for training and testing datasets
    train_it = datagen.flow_from_directory(
        '/kaggle/input/catvsdog/train/',
        batch_size=32,
        target_size=(200, 200),
        class_mode='binary'
    )

    # For testing, no augmentation is applied, only rescaling
    test_datagen = ImageDataGenerator(rescale=1.0 / 255.0)
    test_it = test_datagen.flow_from_directory(
        '/kaggle/input/catvsdog/test/',
        batch_size=32,
        target_size=(200, 200),
        class_mode='binary'
    )

    # Store accuracy and loss values
    train_acc = []
    val_acc = []
    train_loss = []
    val_loss = []

    # Fit the model with correct steps_per_epoch and validation_steps
    history = model.fit(
        train_it,
        validation_data=test_it,
        epochs=50,
    )

    # Extract accuracy and loss values for each epoch
    for epoch in range(50):  # Assuming 40 epochs
        train_acc.append(history.history['accuracy'][epoch])
        val_acc.append(history.history['val_accuracy'][epoch])
        train_loss.append(history.history['loss'][epoch])
        val_loss.append(history.history['val_loss'][epoch])

    # Save the values in a DataFrame or CSV
    data = {
        'Epoch': np.arange(1, 51),
        'Train Accuracy': train_acc,
        'Val Accuracy': val_acc,
        'Train Loss': train_loss,
        'Val Loss': val_loss
    }

    df = pd.DataFrame(data)
    df.to_csv('training_history.csv', index=False)  # Save to CSV in the Colab directory

    print(df)

# %%
run_test_harness()
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Found 20000 images belonging to 2 classes.
# Found 5000 images belonging to 2 classes.
# Epoch 1/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 209s 320ms/step - accuracy: 0.5370 - loss: 0.7780 - val_accuracy: 0.6182 - val_loss: 0.6663
# Epoch 2/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 195s 309ms/step - accuracy: 0.6099 - loss: 0.6530 - val_accuracy: 0.6848 - val_loss: 0.6045
# Epoch 3/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 195s 309ms/step - accuracy: 0.6611 - loss: 0.6071 - val_accuracy: 0.7108 - val_loss: 0.5631
# Epoch 4/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 194s 307ms/step - accuracy: 0.6974 - loss: 0.5763 - val_accuracy: 0.7354 - val_loss: 0.5218
# Epoch 5/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 194s 306ms/step - accuracy: 0.7148 - loss: 0.5486 - val_accuracy: 0.7540 - val_loss: 0.4997
# Epoch 6/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 192s 304ms/step - accuracy: 0.7408 - loss: 0.5206 - val_accuracy: 0.7560 - val_loss: 0.4935
# Epoch 7/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 193s 305ms/step - accuracy: 0.7506 - loss: 0.5035 - val_accuracy: 0.7770 - val_loss: 0.4655
# Epoch 8/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 195s 309ms/step - accuracy: 0.7618 - loss: 0.4926 - val_accuracy: 0.7774 - val_loss: 0.4683
# Epoch 9/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 191s 303ms/step - accuracy: 0.7809 - loss: 0.4695 - val_accuracy: 0.8042 - val_loss: 0.4256
# Epoch 10/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 192s 303ms/step - accuracy: 0.7835 - loss: 0.4604 - val_accuracy: 0.7970 - val_loss: 0.4339
# Epoch 11/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 194s 307ms/step - accuracy: 0.7923 - loss: 0.4496 - val_accuracy: 0.8016 - val_loss: 0.4221
# Epoch 12/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 195s 309ms/step - accuracy: 0.8102 - loss: 0.4330 - val_accuracy: 0.8000 - val_loss: 0.4273
# Epoch 13/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 197s 311ms/step - accuracy: 0.8050 - loss: 0.4284 - val_accuracy: 0.8104 - val_loss: 0.4094
# Epoch 14/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 195s 310ms/step - accuracy: 0.8023 - loss: 0.4299 - val_accuracy: 0.8260 - val_loss: 0.3865
# Epoch 15/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 199s 315ms/step - accuracy: 0.8141 - loss: 0.4177 - val_accuracy: 0.8092 - val_loss: 0.4074
# Epoch 16/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 198s 313ms/step - accuracy: 0.8200 - loss: 0.4050 - val_accuracy: 0.8238 - val_loss: 0.3868
# Epoch 17/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 201s 318ms/step - accuracy: 0.8206 - loss: 0.4067 - val_accuracy: 0.8242 - val_loss: 0.3895
# Epoch 18/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 198s 314ms/step - accuracy: 0.8285 - loss: 0.3934 - val_accuracy: 0.8386 - val_loss: 0.3630
# Epoch 19/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 192s 304ms/step - accuracy: 0.8260 - loss: 0.3933 - val_accuracy: 0.8398 - val_loss: 0.3608
# Epoch 20/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 193s 306ms/step - accuracy: 0.8319 - loss: 0.3864 - val_accuracy: 0.8442 - val_loss: 0.3527
# Epoch 21/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 192s 304ms/step - accuracy: 0.8302 - loss: 0.3849 - val_accuracy: 0.8404 - val_loss: 0.3563
# Epoch 22/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 189s 299ms/step - accuracy: 0.8328 - loss: 0.3837 - val_accuracy: 0.8344 - val_loss: 0.3812
# Epoch 23/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 214s 339ms/step - accuracy: 0.8430 - loss: 0.3699 - val_accuracy: 0.8446 - val_loss: 0.3513
# Epoch 24/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 195s 309ms/step - accuracy: 0.8451 - loss: 0.3598 - val_accuracy: 0.8572 - val_loss: 0.3320
# Epoch 25/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 191s 303ms/step - accuracy: 0.8442 - loss: 0.3646 - val_accuracy: 0.8478 - val_loss: 0.3447
# Epoch 26/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 193s 306ms/step - accuracy: 0.8494 - loss: 0.3543 - val_accuracy: 0.8538 - val_loss: 0.3347
# Epoch 27/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 195s 308ms/step - accuracy: 0.8466 - loss: 0.3547 - val_accuracy: 0.8612 - val_loss: 0.3241
# Epoch 28/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 191s 302ms/step - accuracy: 0.8460 - loss: 0.3500 - val_accuracy: 0.8418 - val_loss: 0.3493
# Epoch 29/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 193s 305ms/step - accuracy: 0.8523 - loss: 0.3399 - val_accuracy: 0.8508 - val_loss: 0.3480
# Epoch 30/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 192s 303ms/step - accuracy: 0.8537 - loss: 0.3335 - val_accuracy: 0.8560 - val_loss: 0.3285
# Epoch 31/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 190s 301ms/step - accuracy: 0.8555 - loss: 0.3323 - val_accuracy: 0.8572 - val_loss: 0.3251
# Epoch 32/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 190s 302ms/step - accuracy: 0.8578 - loss: 0.3295 - val_accuracy: 0.8598 - val_loss: 0.3236
# Epoch 33/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 190s 301ms/step - accuracy: 0.8597 - loss: 0.3306 - val_accuracy: 0.8654 - val_loss: 0.3143
# Epoch 34/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 193s 305ms/step - accuracy: 0.8632 - loss: 0.3196 - val_accuracy: 0.8586 - val_loss: 0.3291
# Epoch 35/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 194s 307ms/step - accuracy: 0.8647 - loss: 0.3200 - val_accuracy: 0.8676 - val_loss: 0.3087
# Epoch 36/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 193s 305ms/step - accuracy: 0.8646 - loss: 0.3212 - val_accuracy: 0.8638 - val_loss: 0.3135
# Epoch 37/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 194s 306ms/step - accuracy: 0.8639 - loss: 0.3195 - val_accuracy: 0.8690 - val_loss: 0.2971
# Epoch 38/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 191s 303ms/step - accuracy: 0.8741 - loss: 0.3086 - val_accuracy: 0.8716 - val_loss: 0.2977
# Epoch 39/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 194s 306ms/step - accuracy: 0.8704 - loss: 0.3068 - val_accuracy: 0.8682 - val_loss: 0.2981
# Epoch 40/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 195s 309ms/step - accuracy: 0.8696 - loss: 0.3073 - val_accuracy: 0.8714 - val_loss: 0.2937
# Epoch 41/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 191s 303ms/step - accuracy: 0.8713 - loss: 0.3040 - val_accuracy: 0.8628 - val_loss: 0.3230
# Epoch 42/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 192s 305ms/step - accuracy: 0.8749 - loss: 0.2996 - val_accuracy: 0.8774 - val_loss: 0.2844
# Epoch 43/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 194s 307ms/step - accuracy: 0.8772 - loss: 0.2956 - val_accuracy: 0.8728 - val_loss: 0.2972
# Epoch 44/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 193s 306ms/step - accuracy: 0.8774 - loss: 0.2925 - val_accuracy: 0.8730 - val_loss: 0.2898
# Epoch 45/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 192s 304ms/step - accuracy: 0.8780 - loss: 0.2900 - val_accuracy: 0.8762 - val_loss: 0.2911
# Epoch 46/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 195s 309ms/step - accuracy: 0.8809 - loss: 0.2857 - val_accuracy: 0.8784 - val_loss: 0.2809
# Epoch 47/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 198s 313ms/step - accuracy: 0.8829 - loss: 0.2858 - val_accuracy: 0.8776 - val_loss: 0.2857
# Epoch 48/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 197s 312ms/step - accuracy: 0.8796 - loss: 0.2862 - val_accuracy: 0.8722 - val_loss: 0.2908
# Epoch 49/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 192s 305ms/step - accuracy: 0.8821 - loss: 0.2781 - val_accuracy: 0.8836 - val_loss: 0.2819
# Epoch 50/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 192s 304ms/step - accuracy: 0.8899 - loss: 0.2704 - val_accuracy: 0.8840 - val_loss: 0.2799
#     Epoch  Train Accuracy  Val Accuracy  Train Loss  Val Loss
# 0       1         0.54960        0.6182    0.702924  0.666318
# 1       2         0.62155        0.6848    0.642108  0.604546
# 2       3         0.66680        0.7108    0.601736  0.563089
# 3       4         0.70250        0.7354    0.570021  0.521765
# 4       5         0.71965        0.7540    0.543500  0.499675
# 5       6         0.73880        0.7560    0.521930  0.493534
# 6       7         0.75615        0.7770    0.499519  0.465538
# 7       8         0.76555        0.7774    0.488696  0.468261
# 8       9         0.78100        0.8042    0.470164  0.425593
# 9      10         0.78620        0.7970    0.458149  0.433911
# 10     11         0.79235        0.8016    0.447425  0.422121
# 11     12         0.80300        0.8000    0.437655  0.427284
# 12     13         0.80485        0.8104    0.429692  0.409412
# 13     14         0.80745        0.8260    0.424491  0.386459
# 14     15         0.81260        0.8092    0.417076  0.407393
# 15     16         0.81770        0.8238    0.407888  0.386781
# 16     17         0.82145        0.8242    0.404345  0.389455
# 17     18         0.82775        0.8386    0.394834  0.363033
# 18     19         0.82620        0.8398    0.392684  0.360791
# 19     20         0.82930        0.8442    0.386851  0.352699
# 20     21         0.83125        0.8404    0.382475  0.356257
# 21     22         0.83615        0.8344    0.375607  0.381208
# 22     23         0.84300        0.8446    0.368305  0.351262
# 23     24         0.83970        0.8572    0.363918  0.332009
# 24     25         0.84635        0.8478    0.359056  0.344692
# 25     26         0.84840        0.8538    0.352877  0.334749
# 26     27         0.84390        0.8612    0.357508  0.324101
# 27     28         0.85020        0.8418    0.347777  0.349312
# 28     29         0.85345        0.8508    0.340448  0.348020
# 29     30         0.85165        0.8560    0.338368  0.328465
# 30     31         0.85470        0.8572    0.337735  0.325094
# 31     32         0.85730        0.8598    0.333031  0.323589
# 32     33         0.86075        0.8654    0.326418  0.314334
# 33     34         0.86145        0.8586    0.325413  0.329084
# 34     35         0.86505        0.8676    0.321207  0.308744
# 35     36         0.86575        0.8638    0.320690  0.313511
# 36     37         0.86630        0.8690    0.316374  0.297126
# 37     38         0.87105        0.8716    0.310321  0.297747
# 38     39         0.86870        0.8682    0.308448  0.298053
# 39     40         0.86785        0.8714    0.310332  0.293708
# 40     41         0.86995        0.8628    0.305967  0.323020
# 41     42         0.87600        0.8774    0.299470  0.284414
# 42     43         0.87550        0.8728    0.297851  0.297157
# 43     44         0.87835        0.8730    0.293872  0.289773
# 44     45         0.87840        0.8762    0.291268  0.291121
# 45     46         0.87815        0.8784    0.290567  0.280897
# 46     47         0.88340        0.8776    0.283326  0.285651
# 47     48         0.88040        0.8722    0.284774  0.290824
# 48     49         0.88365        0.8836    0.277697  0.281853
# 49     50         0.88460        0.8840    0.277708  0.279899

# %%
plot_from_csv('training_history.csv')

# %%
from keras.layers import BatchNormalization

# %%
def define_model():
    model = Sequential()
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform',
                     padding='same', input_shape=(200, 200, 3)))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.1))

    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform',
                     padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.1))

    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform',
                     padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.1))

    model.add(Flatten())
    model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
    model.add(Dropout(0.3))

    model.add(Dense(1, activation='sigmoid'))

    # Compile the model
    opt = Adam(learning_rate=0.0001)
    model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])

    return model

# %%
import numpy as np
import pandas as pd


# Define the test harness
def run_test_harness():
    model = define_model()

    # Data augmentation configuration
    datagen = ImageDataGenerator(
        rescale=1.0 / 255.0,
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip=True
    )

    # Prepare iterators for training and testing datasets
    train_it = datagen.flow_from_directory(
        '/kaggle/input/catvsdog/train/',
        batch_size=32,
        target_size=(200, 200),
        class_mode='binary'
    )

    # For testing, no augmentation is applied, only rescaling
    test_datagen = ImageDataGenerator(rescale=1.0 / 255.0)
    test_it = test_datagen.flow_from_directory(
        '/kaggle/input/catvsdog/test/',
        batch_size=32,
        target_size=(200, 200),
        class_mode='binary'
    )

    # Store accuracy and loss values
    train_acc = []
    val_acc = []
    train_loss = []
    val_loss = []

    # Fit the model with correct steps_per_epoch and validation_steps
    history = model.fit(
        train_it,
        validation_data=test_it,
        epochs=80,
    )

    # Extract accuracy and loss values for each epoch
    for epoch in range(80):  # Assuming 40 epochs
        train_acc.append(history.history['accuracy'][epoch])
        val_acc.append(history.history['val_accuracy'][epoch])
        train_loss.append(history.history['loss'][epoch])
        val_loss.append(history.history['val_loss'][epoch])

    # Save the values in a DataFrame or CSV
    data = {
        'Epoch': np.arange(1, 81),
        'Train Accuracy': train_acc,
        'Val Accuracy': val_acc,
        'Train Loss': train_loss,
        'Val Loss': val_loss
    }

    df = pd.DataFrame(data)
    df.to_csv('training_history.csv', index=False)  # Save to CSV in the Colab directory

    print(df)

# %%
run_test_harness()
# Out:
# Found 20000 images belonging to 2 classes.
# Found 5000 images belonging to 2 classes.
# Epoch 1/80
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 206s 312ms/step - accuracy: 0.6124 - loss: 0.7725 - val_accuracy: 0.7128 - val_loss: 0.5560
# Epoch 2/80
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 193s 305ms/step - accuracy: 0.6901 - loss: 0.5752 - val_accuracy: 0.7586 - val_loss: 0.5043
# Epoch 3/80
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 193s 305ms/step - accuracy: 0.7282 - loss: 0.5313 - val_accuracy: 0.7862 - val_loss: 0.4545
# Epoch 4/80
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 193s 305ms/step - accuracy: 0.7502 - loss: 0.5073 - val_accuracy: 0.7878 - val_loss: 0.4492
# Epoch 5/80
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 194s 307ms/step - accuracy: 0.7694 - loss: 0.4803 - val_accuracy: 0.7848 - val_loss: 0.4485
# Epoch 6/80
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 193s 305ms/step - accuracy: 0.7806 - loss: 0.4556 - val_accuracy: 0.8156 - val_loss: 0.4116
# Epoch 7/80
# 316/625 ━━━━━━━━━━━━━━━━━━━━ 1:29 288ms/step - accuracy: 0.7827 - loss: 0.4635
